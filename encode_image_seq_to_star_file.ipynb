# %%
'''
Input: a directory (string ending in '/') containing a sequence of .png images that resulted from exporting a .gif to an image sequence in Photoshop
Output: a .star file called  <output> that contains each image encoded with base64 on its own line of the text file.

Once the .star file is created, use 'pixlet render <this file>' to render the resulting .star file as a .webp animation and
use 'pixlet push <tidbyt-device-id> <.webp file>' to view it on your Tidbyt. The .webp file resulting from the 'pixlet render'
command may need to be compressed to avoid errors when pushing it to your Tidbyt.
'''
def encode_image_sequence_to_starfile(directory, output):
    import os
    import base64
    
    # get list of files in provided directory
    files = os.listdir(directory)
    
    # loop through each file and encode it to base64
    imgs = []
    encoded_imgs = []
    i = 0
    
    # get .png files
    for file in files:
        if '.png' in file:
            imgs.append(file)
    
    # loop through png files and convert to base64
    for img in imgs:
        i+=1
        with open(directory + img, "rb") as img_file:
            img_string = base64.b64encode(img_file.read())
        img_string = img_string.decode('utf-8')
        if i == 1:
            encoded_imgs.append('"""' + img_string + '""",')
        else:
            encoded_imgs.append('\t\t\t"""' + img_string + '""",')
        print('Encoded image', str(i), 'of', str(len(imgs)) + '.')
        
    # write encoded strings to file
    with open(directory + 'frames.txt', 'w') as f:
        f.write('\n'.join(encoded_imgs))
        
    # A Simple Python template example
    from string import Template

    
    starfile_templatedata = 'load("encoding/base64.star", "base64")\nload("render.star", "render")\nload("schema.star", "schema")\nload("time.star", "time")\n\ndef main(config):\n    seed = int(time.now().unix)\n    seed = [seed]\n\n\n    # FRAMES\n    FRAMES = [\n\t\t\t$frames\n            ]\n\n   \n    return render.Root(\n        child = render.Animation(\n            children = [render.Image(src = base64.decode(f)) for f in FRAMES],\n        ),\n        delay = 30,\n    )'

    with open(directory + 'frames.txt', 'r') as frames_file:
        framedata = frames_file.read()

    t = Template(starfile_templatedata)

    sub_t = t.substitute({'frames' : framedata})

    with open(directory + output, 'w') as f:
        f.write(sub_t)
        
    print('\nImage sequence written to', directory + output + '.')

# %%
encode_image_sequence_to_starfile('GBA_anims/F-Zero/', 'fzero_anim.star')
# Out:
# Encoded image 1 of 177.
# Encoded image 2 of 177.
# Encoded image 3 of 177.
# Encoded image 4 of 177.
# Encoded image 5 of 177.
# Encoded image 6 of 177.
# Encoded image 7 of 177.
# Encoded image 8 of 177.
# Encoded image 9 of 177.
# Encoded image 10 of 177.
# Encoded image 11 of 177.
# Encoded image 12 of 177.
# Encoded image 13 of 177.
# Encoded image 14 of 177.
# Encoded image 15 of 177.
# Encoded image 16 of 177.
# Encoded image 17 of 177.
# Encoded image 18 of 177.
# Encoded image 19 of 177.
# Encoded image 20 of 177.
# Encoded image 21 of 177.
# Encoded image 22 of 177.
# Encoded image 23 of 177.
# Encoded image 24 of 177.
# Encoded image 25 of 177.
# Encoded image 26 of 177.
# Encoded image 27 of 177.
# Encoded image 28 of 177.
# Encoded image 29 of 177.
# Encoded image 30 of 177.
# Encoded image 31 of 177.
# Encoded image 32 of 177.
# Encoded image 33 of 177.
# Encoded image 34 of 177.
# Encoded image 35 of 177.
# Encoded image 36 of 177.
# Encoded image 37 of 177.
# Encoded image 38 of 177.
# Encoded image 39 of 177.
# Encoded image 40 of 177.
# Encoded image 41 of 177.
# Encoded image 42 of 177.
# Encoded image 43 of 177.
# Encoded image 44 of 177.
# Encoded image 45 of 177.
# Encoded image 46 of 177.
# Encoded image 47 of 177.
# Encoded image 48 of 177.
# Encoded image 49 of 177.
# Encoded image 50 of 177.
# Encoded image 51 of 177.
# Encoded image 52 of 177.
# Encoded image 53 of 177.
# Encoded image 54 of 177.
# Encoded image 55 of 177.
# Encoded image 56 of 177.
# Encoded image 57 of 177.
# Encoded image 58 of 177.
# Encoded image 59 of 177.
# Encoded image 60 of 177.
# Encoded image 61 of 177.
# Encoded image 62 of 177.
# Encoded image 63 of 177.
# Encoded image 64 of 177.
# Encoded image 65 of 177.
# Encoded image 66 of 177.
# Encoded image 67 of 177.
# Encoded image 68 of 177.
# Encoded image 69 of 177.
# Encoded image 70 of 177.
# Encoded image 71 of 177.
# Encoded image 72 of 177.
# Encoded image 73 of 177.
# Encoded image 74 of 177.
# Encoded image 75 of 177.
# Encoded image 76 of 177.
# Encoded image 77 of 177.
# Encoded image 78 of 177.
# Encoded image 79 of 177.
# Encoded image 80 of 177.
# Encoded image 81 of 177.
# Encoded image 82 of 177.
# Encoded image 83 of 177.
# Encoded image 84 of 177.
# Encoded image 85 of 177.
# Encoded image 86 of 177.
# Encoded image 87 of 177.
# Encoded image 88 of 177.
# Encoded image 89 of 177.
# Encoded image 90 of 177.
# Encoded image 91 of 177.
# Encoded image 92 of 177.
# Encoded image 93 of 177.
# Encoded image 94 of 177.
# Encoded image 95 of 177.
# Encoded image 96 of 177.
# Encoded image 97 of 177.
# Encoded image 98 of 177.
# Encoded image 99 of 177.
# Encoded image 100 of 177.
# Encoded image 101 of 177.
# Encoded image 102 of 177.
# Encoded image 103 of 177.
# Encoded image 104 of 177.
# Encoded image 105 of 177.
# Encoded image 106 of 177.
# Encoded image 107 of 177.
# Encoded image 108 of 177.
# Encoded image 109 of 177.
# Encoded image 110 of 177.
# Encoded image 111 of 177.
# Encoded image 112 of 177.
# Encoded image 113 of 177.
# Encoded image 114 of 177.
# Encoded image 115 of 177.
# Encoded image 116 of 177.
# Encoded image 117 of 177.
# Encoded image 118 of 177.
# Encoded image 119 of 177.
# Encoded image 120 of 177.
# Encoded image 121 of 177.
# Encoded image 122 of 177.
# Encoded image 123 of 177.
# Encoded image 124 of 177.
# Encoded image 125 of 177.
# Encoded image 126 of 177.
# Encoded image 127 of 177.
# Encoded image 128 of 177.
# Encoded image 129 of 177.
# Encoded image 130 of 177.
# Encoded image 131 of 177.
# Encoded image 132 of 177.
# Encoded image 133 of 177.
# Encoded image 134 of 177.
# Encoded image 135 of 177.
# Encoded image 136 of 177.
# Encoded image 137 of 177.
# Encoded image 138 of 177.
# Encoded image 139 of 177.
# Encoded image 140 of 177.
# Encoded image 141 of 177.
# Encoded image 142 of 177.
# Encoded image 143 of 177.
# Encoded image 144 of 177.
# Encoded image 145 of 177.
# Encoded image 146 of 177.
# Encoded image 147 of 177.
# Encoded image 148 of 177.
# Encoded image 149 of 177.
# Encoded image 150 of 177.
# Encoded image 151 of 177.
# Encoded image 152 of 177.
# Encoded image 153 of 177.
# Encoded image 154 of 177.
# Encoded image 155 of 177.
# Encoded image 156 of 177.
# Encoded image 157 of 177.
# Encoded image 158 of 177.
# Encoded image 159 of 177.
# Encoded image 160 of 177.
# Encoded image 161 of 177.
# Encoded image 162 of 177.
# Encoded image 163 of 177.
# Encoded image 164 of 177.
# Encoded image 165 of 177.
# Encoded image 166 of 177.
# Encoded image 167 of 177.
# Encoded image 168 of 177.
# Encoded image 169 of 177.
# Encoded image 170 of 177.
# Encoded image 171 of 177.
# Encoded image 172 of 177.
# Encoded image 173 of 177.
# Encoded image 174 of 177.
# Encoded image 175 of 177.
# Encoded image 176 of 177.
# Encoded image 177 of 177.
#
# Image sequence written to fzero_anim.star.
